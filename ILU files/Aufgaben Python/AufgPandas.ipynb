# %% [markdown]
# # Pandas Aufgaben

# %% [markdown]
# ## Notwendige Bibliotheken

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# $\color{green}{\textbf{Grüne Schrift}}$: Zuteilung der Aufgaben zu bestimmten Teilnehmern (Usern). Es sind jeweils die Aufgaben bis zum nächsten $\color{green}{\textbf{User}}$ Marker (oder bis zum Ende des Notebooks) zu lösen.

# %% [markdown]
# ## Einlesen und Erweitern

# %% [markdown]
# $\color{green}{\textbf{User 15}}$:

# %% [markdown]
# $\color{blue}{\text{Aufgabe 1}}$. Laden Sie mithilfe des Packages `datasets` aus `sklearn` den Datensatz $\color{red}{\text{Iris}}$ und konvertieren Sie ihn in ein Pandas DataFrame ``df``. Fallweise als Hilfestellung: [https://medium.com/analytics-vidhya/built-in-datasets-in-python-24adca42012c]. Ermitteln Sie mit ``datasets.load_iris().feature_names`` die Namen aller Features und ordnen Sie diese den Spalten von ``df`` als Namen zu.

# %% [markdown]
# $\color{blue}{\text{Aufgabe 2a}}$. In einem **Pandas** DataFrame enthalten die Zeilen unterschiedliche Records (Instanzen) der Daten und die Spalten unterschiedliche Features (Variablen, Ausprägungen) der Daten. Verschiedene Spalten können verschiedene Datentypen (String, float, int) enthalten.
#
# Wie viele Records (Zeilen) und wie viele Features (Spalten) hat der Datensatz $\color{red}{\text{Iris}}$? Geben Sie die Namen aller Features aus.

# %% [markdown]
# $\color{blue}{\text{Aufgabe 2b}}$. Bestimmen Sie (mit nur *einer* Befehlszeile!) für jede Spalte des $\color{red}{\text{Iris}}$ Datensatzes Mittelwert, Standardabweichung, Min und Max, 25%, 50% und 75%-Quantil.

# %% [markdown]
# $\color{green}{\textbf{User 16}}$:

# %% [markdown]
# $\color{blue}{\text{Aufgabe 3}}$. Erzeugen Sie eine Kopie des $\color{red}{\text{Iris}}$ Datensatzes und fügen Sie dieser Kopie
# - eine Zeile mit den Werten 1,2,3,4 und
# - eine Spalte `mycolumn` mit den Werten 0,1,...,150
# hinzu

# %% [markdown]
# ## Selektieren, Berechnen, Visualisieren

# %% [markdown]
# $\color{green}{\textbf{User 17}}$:

# %% [markdown]
# $\color{blue}{\text{Aufgabe 4}}$. In ILIAS finden Sie unter ``Data/``die Datei ``pizza.csv`` mit dem $\color{red}{\text{Pizza}}$ Datensatz. Schauen Sie sich die Daten mit einem Editor an und lesen Sie dann die Daten mit passenden Argumenten als Pandas DataFrame ein. Geben Sie den Spalten die Namen X, Y, Pizza.

# %% [markdown]
# $\color{blue}{\text{Aufgabe 5}}$. Visualisieren Sie die $\color{red}{\text{Pizza}}$ Daten (aus $\color{blue}{\text{Aufg. 4}}$) mit einem Scatterplot (`X` vs. `Y`). Färben Sie die Scatter-Punkte gemäß ihrem `Pizza` Wert unterschiedlich ein.

# %% [markdown]
# $\color{blue}{\text{Aufgabe 6}}$
# * Entnehmen Sie dem $\color{red}{\text{Iris}}$ Datensatz die Spalten $s_l =$ `sepal length` und $s_w =$ `sepal width` als NumPy Array.
# * Erstellen Sie eine neue Spalte $\sqrt{s_l^2 + s_w^2}$, die Sie dem NumPy Array hinzufügen.
# * Geben Sie die ersten 5 Records aus.
# * Wandeln Sie wieder in ein Pandas DataFrame zurück.

# %% [markdown]
# ## Visualisieren, Vergleich Pandas Numpy

# %% [markdown]
# $\color{green}{\textbf{User 18}}$:

# %% [markdown]
# $\color{blue}{\text{Aufgabe 7}}$.
#
# (a) Visualisieren Sie die $\color{red}{\text{Iris}}$ Daten in einem Boxplot (für jedes Feature eigene Box). Nutzen Sie Argument `figsize`, um den Plot genügend breit zu machen.
#
# (b) Machen Sie einen Boxplot, der nur die `sepal...`-Features enthält.

# %% [markdown]
# $\color{blue}{\text{Aufgabe 8}}$
#
# 1.   Nenne einige Dinge, die man mit Pandas, aber nicht mit NumPy machen kann.
# 2.   Nenne einige Dinge, die man mit NumPy, aber nicht mit Pandas machen kann.
#
# ---
